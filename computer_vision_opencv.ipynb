# %% [markdown]
# # What are Images?

# %% [markdown]
# Images in opencv are numpy arrays.
#
# An image is made by "pixels"
#
# Pixel is the basic component of image.
#
# In most cases pixel values range from 0 to 255
#
# In binary images pixel values is in [0, 1] (of [0, 255]).
#
#
# In 16 bits images pixel value range from 0 to 65535.
#
# Generally we work with 8 bit images ranging from 0 to 255.

# %%
import cv2

# %% [markdown]
# # Datatype of images

# %%
a = cv2.imread(
    'download (1).jpg'
)

print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Checking the shape of the image

# %%
# shape of image
image = cv2.imread('download (1).jpg')
print(image.shape)
# height  weight  and number of channels 

# the 3 channels are Blue component, Green Component and Red Component
# Out:
# (123, 259, 3)

# %% [markdown]
# ## Input and Output data using Opencv

# %% [markdown]
# 1. For Image

# %%
import os

# %%
# reading the image 
image_path = os.path.join('.',  'download (1).jpg')
img = cv2.imread(image_path)


# writing image
cv2.imwrite(os.path.join('.',  'car.jpg'), img)
# Out:
# True

# %%
# visualizing image
from matplotlib import pyplot as plt

img = cv2.imread('car.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# cv2.imshow('image', img)
# cv2.waitKey(0)

# %% [markdown]
# 2. For Video

# %%
import os
# read video
video_path = os.path.join('.', 'video.mp4')
video = cv2.VideoCapture(video_path)

# %%
# # visualize video
# ret = True
# while ret:
#     ret, frame = video.read()
#     if ret:
#         cv2.imshow('frame', frame)
#         cv2.waitKey(40)

# video.release()
# cv2.destroyAllWindows()

# %% [markdown]
# 3. For webcam

# %%
# read webcam 
webcam = cv2.VideoCapture(0)

# # visualize webcam
# while True:
#     ret, frame = webcam.read()
#     cv2.imshow('frame', frame)
#     if cv2.waitKey(40) & 0xFF == ord('q'):
#         break

# webcam.release()
# cv2.destroyAllWindows()

# %% [markdown]
# Basic Operation of image

# %% [markdown]
# 1. resizing image

# %%
# resizing image 
img = cv2.imread(os.path.join('.', 'car.jpg'))
resized_image = cv2.resize(img, (640, 480)) # height and width of image
print(img.shape)
print(resized_image.shape)

cv2.imshow('img', img)
cv2.imshow('resized_img', resized_image)
cv2.waitKey(0)
# Out:
# (123, 259, 3)
# (480, 640, 3)

# %% [markdown]
# 2. Cropping Image

# %%
import os
import cv2
img = cv2.imread(os.path.join('.', 'car.jpg'))
print(img.shape)

cropped_img = img[90:120, 190:200]

cv2.imshow('img', img)
cv2.imshow('cropped_img', cropped_img)
cv2.waitKey(0)
# Out:
# (123, 259, 3)
# -1

# %% [markdown]
# # Colorspaces

# %%
import os
import cv2
img = cv2.imread(os.path.join('.', 'car.jpg'))
cv2.imshow('img', img)


img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imshow('img_rgb', img_rgb)


img_grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow('img_grey', img_grey)


img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
cv2.imshow('img_hsv', img_hsv)

cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Image Blurring

# %% [markdown]
# Functions
#
# 1. blur()
#
# 2. GaussianBlur()
#
# 3. medianBlur()
#
# 4. bilateralFilter()

# %%
import os
import cv2

img = cv2.imread(os.path.join('.', 'sample.jpg'))

k_size = 70
img_blur = cv2.blur(img, (k_size, k_size))


cv2.imshow('img', img)
cv2.imshow('img_blur', img_blur)
cv2.waitKey(0)
# Out:
# -1

# %%
import os
import cv2

img = cv2.imread(os.path.join('.', 'quote.jpg'))

k_size = 7
img_gaussion_blur = cv2.GaussianBlur(img, (k_size, k_size), 3)


cv2.imshow('img', img)
cv2.imshow('img_gaussion_blur', img_gaussion_blur)
cv2.waitKey(0)
# Out:
# -1

# %%
import os
import cv2

img = cv2.imread(os.path.join('.', 'quote.jpg'))

k_size = 7
img_median_blur = cv2.medianBlur(img, k_size)


cv2.imshow('img', img)
cv2.imshow('img_median_blur', img_median_blur)
cv2.waitKey(0)

# median blur is quite good than other
# Out:
# -1

# %% [markdown]
# # Removing noise in the image

# %%
import os
import cv2

img = cv2.imread(os.path.join('.', 'blur.jpg'))

k_size = 7
img_median_blur = cv2.medianBlur(img, k_size)


cv2.imshow('img', img)
cv2.imshow('img_median_blur', img_median_blur)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Thresholding
